# %%
from utils.gi_driver import load_images_multiprocessing

# %%
load_images_multiprocessing(
    output_directory='data/images',
    process_count=16,
    batch_size=1
)
# Out:
# Item no.: 1 --> Item name = chinese characters
# Item no.: 1 --> Item name = chinese gazette
# Item no.: 1 --> Item name = chinese letter
# Item no.: 1 --> Item name = asian journal
#
# Item no.: 1 --> Item name = chinese contents
# Item no.: 1 --> Item name = chinese letters
#
# Item no.: 1 --> Item name = chinese newspapers
#
#
# Item no.: 1 --> Item name = chinese magazine
# Item no.: 1 --> Item name = chinese textsEvaluating...
#
# Item no.: 1 --> Item name = asian review
#
# Evaluating...
# Evaluating...
# Evaluating...
# Evaluating...
#
# Item no.: 1 --> Item name = chinese paragraph
# Item no.: 1 --> Item name = asian lines
# Item no.: 1 --> Item name = asian newspaper
# Item no.: 1 --> Item name = chinese text
#
# Item no.: 1 --> Item name = asian documents
# Item no.: 1 --> Item name = asian journals
#
# Evaluating...
#
#
# Evaluating...
#
# Evaluating...
#
#
# Evaluating...
#
#
# Evaluating...
# Evaluating...
# Evaluating...
# Evaluating...
# Evaluating...
# Evaluating...
# ...
