# %%
# !rm -rf ./chinese-ausweis-viewer
# !git clone https://github.com/sdlm/chinese-ausweis-viewer.git
# Out:
# Cloning into 'chinese-ausweis-viewer'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 52 (delta 7), reused 47 (delta 6), pack-reused 0
# Unpacking objects: 100% (52/52), done.

# %%
# %run ./chinese-ausweis-viewer/chinese_ausweis_viewer/unet.py
# %run ./chinese-ausweis-viewer/chinese_ausweis_viewer/helpers.py

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
h_size = 256
w_size = 256
start_neurons = 16
model = get_compiled_model(h_size, w_size, start_neurons)
model.load_weights('./chinese-ausweis-viewer/chinese_ausweis_viewer/data/weights/model_v1.h5')

# %%
import imageio
sample_img = imageio.imread('/content/gdrive/My Drive/colab/original_sample_blur_1000.jpg', pilmode="RGB")
original_smpl = np.array(sample_img, dtype=np.uint8)

mask_img = imageio.imread('/content/gdrive/My Drive/colab/original_sample_mask_inv_1000.jpg', pilmode="RGB", as_gray=True)
original_mask = np.array(mask_img, dtype=np.uint8)

# %%
test_img = imageio.imread('/content/gdrive/My Drive/colab/original_sample_blur2_256.jpg', pilmode="RGB")
test_arr = np.array(test_img, dtype=np.uint8) / 255.0
show_predict_mask_above_image(test_arr, model, h_size, w_size)

# %%
test_img = imageio.imread('/content/gdrive/My Drive/colab/test/test_004.jpg', pilmode="RGB")
test_arr = np.array(test_img, dtype=np.uint8) / 255.0
show_predict_mask_above_image(test_arr, model, h_size, w_size)
